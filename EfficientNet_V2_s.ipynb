# %%
# !unzip /content/drive/MyDrive/NEGATIVE.zip  -d /content
# !unzip /content/drive/MyDrive/POSITIVE.zip  -d /content
# !unzip /content/drive/MyDrive/POSITIVEGAN.zip  -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/29087_951624387.png
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/28959_407797154.png
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/46144_112792357.png
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/21304_1273578482.png
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/2516_992751859.png
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/2182_2067189673.png
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/6685_2127534398.png
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/28914_1080307280.png
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/43539_765637762.png
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/44626_1988104905.png
#   inflating: /content/content/Licenta/Processed_RSNA2/NEGATIVE/11107_1843457717.png
# ...

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms, models
from sklearn.model_selection import train_test_split
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score


data_dir = 'content/Licenta/Processed_RSNA2/'
image_paths = []
for root, dirs, files in os.walk(data_dir):
    for file in files:
        if file.endswith('.png'):
            image_paths.append(os.path.join(root, file))
labels = [os.path.basename(os.path.dirname(path)) for path in image_paths]
train_paths, test_paths, train_labels, test_labels = train_test_split(image_paths, labels, test_size=0.1, random_state=90, stratify=labels)

# Get positive images
positive_dir = 'POSITIVE/'
positive_paths = []
for root, dirs, files in os.walk(positive_dir):
    for file in files:
        if file.endswith('.png'):
            positive_paths.append(os.path.join(root, file))
positive_labels = ['POSITIVE' for _ in positive_paths]

# Concatenate positive images to the training set
train_paths.extend(positive_paths)
train_labels.extend(positive_labels)

print(f'Training set: {len(train_paths)} images')
print(f'Test set: {len(test_paths)} images')
# Custom dataset
class CustomDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = self.dataframe.iloc[idx, 0]
        image = Image.open(img_name).convert('L')
        label = 0 if self.dataframe.iloc[idx, 1] == 'NEGATIVE' else 1

        if self.transform:
            image = self.transform(image)

        return image, label

# Data transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(train_paths, train_labels, test_size=0.2, random_state=42, stratify=train_labels)

train_df = pd.DataFrame({'path': X_train, 'label': y_train})
val_df = pd.DataFrame({'path': X_val, 'label': y_val})

train_dataset = CustomDataset(dataframe=train_df, transform=transform)
val_dataset = CustomDataset(dataframe=val_df, transform=test_transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=0)



# Load the EfficientNet model
model = models.efficientnet_v2_s(pretrained=False)

# Modify the input layer to accept grayscale images instead of RGB
# Identify the correct attribute based on the model structure
conv_layer = model.features[0][0]

new_conv_layer = nn.Conv2d(1, conv_layer.out_channels,
                           kernel_size=conv_layer.kernel_size,
                           stride=conv_layer.stride,
                           padding=conv_layer.padding,
                           bias=False)

new_conv_layer.requires_grad = False  # Set requires_grad to False
model.features[0][0] = new_conv_layer

# Modify the output layer for binary classification
num_ftrs = model.classifier._modules['1'].in_features
model.classifier._modules['1'] = nn.Linear(num_ftrs, 1)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# Loss and optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training the model
num_epochs = 30
patience = 10  # Patience for early stopping
best_loss = None
epochs_no_improve = 0
training_losses = []
validation_losses = []
precisions_train = []
recalls_train = []
precisions_val = []
recalls_val = []

for epoch in range(num_epochs):
    # Training
    model.train()
    total_training_loss = 0
    all_training_labels = []
    all_training_preds = []
    for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1} Training'):
        inputs, labels = inputs.to('cuda'), labels.to('cuda').float().unsqueeze(1)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_training_loss += loss.item()
        training_preds = (torch.sigmoid(outputs).detach().cpu().numpy() > 0.5).astype(int)
        all_training_preds.extend(training_preds)
        all_training_labels.extend(labels.cpu().numpy())
    average_training_loss = total_training_loss / len(train_loader)
    training_losses.append(average_training_loss)

    # Calculate precision and recall for training set
    training_precision = precision_score(all_training_labels, all_training_preds)
    training_recall = recall_score(all_training_labels, all_training_preds)
    precisions_train.append(training_precision)
    recalls_train.append(training_recall)

    # Validation
    model.eval()
    total_validation_loss = 0
    all_validation_labels = []
    all_validation_preds = []
    with torch.no_grad():
        val_losses = []
        for inputs, labels in tqdm(val_loader, desc=f'Epoch {epoch + 1} Validation'):
            inputs, labels = inputs.to('cuda'), labels.to('cuda').float().unsqueeze(1)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_losses.append(loss.item())
            validation_preds = torch.sigmoid(outputs).cpu().numpy() > 0.5
            all_validation_preds.extend(validation_preds)
            all_validation_labels.extend(labels.cpu().numpy())

    avg_val_loss = sum(val_losses) / len(val_losses)
    validation_losses.append(avg_val_loss)

    # Calculate precision and recall for validation set
    validation_precision = precision_score(all_validation_labels, all_validation_preds)
    validation_recall = recall_score(all_validation_labels, all_validation_preds)
    precisions_val.append(validation_precision)
    recalls_val.append(validation_recall)

    print(f'Epoch [{epoch+1}/{num_epochs}], '
          f'Training Loss: {average_training_loss:.4f}, Training Precision: {training_precision:.4f}, '
          f'Training Recall: {training_recall:.4f}, '
          f'Validation Loss: {avg_val_loss:.4f}, Validation Precision: {validation_precision:.4f}, '
          f'Validation Recall: {validation_recall:.4f}')

    # Checkpoint and Early Stopping
    if best_loss is None:
        best_loss = avg_val_loss
        torch.save(model.state_dict(), f'EffNet_best1.pth')
    elif avg_val_loss < best_loss:
        epochs_no_improve = 0
        best_loss = avg_val_loss
        torch.save(model.state_dict(), f'EffNet_best1.pth')
        print(f'Validation loss decreased. Saving the model to EffNet_best1.pth')
    else:
        epochs_no_improve += 1
        if epochs_no_improve == patience:
            print('Early stopping')
            break
actual_epochs = len(training_losses)
# After the training is complete, plot the metrics:
# Plot Training Loss
plt.figure(figsize=(6, 4))
plt.plot(range(1, actual_epochs + 1), training_losses, label='Training Loss')
plt.plot(range(1, actual_epochs + 1), validation_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# Plot Training Precision
plt.figure(figsize=(6, 4))
plt.plot(range(1, actual_epochs + 1), precisions_train, label='Training Precision')
plt.plot(range(1, actual_epochs + 1), precisions_val, label='Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.title('Training and Validation Precision')
plt.show()

# Plot Training Recall
plt.figure(figsize=(6, 4))
plt.plot(range(1, actual_epochs + 1), recalls_train, label='Training Recall')
plt.plot(range(1, actual_epochs + 1), recalls_val, label='Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.title('Training and Validation Recall')
plt.show()
# Out:
# Training set: 52215 images
# Test set: 5462 images
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ...
# Epoch 1 Validation: 100%|██████████| 164/164 [01:28<00:00,  1.86it/s]
# Epoch [1/30], Training Loss: 0.1748, Training Precision: 0.8361, Training Recall: 0.5584, Validation Loss: 0.1092, Validation Precision: 0.9880, Validation Recall: 0.7012
# ...
# Epoch 2 Validation: 100%|██████████| 164/164 [01:28<00:00,  1.86it/s]
# ...

# %%
from sklearn.metrics import confusion_matrix

test_dataset = CustomDataset(dataframe=pd.DataFrame({'path': test_paths, 'label': test_labels}), transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=0)

# %%
# Load the saved model
model = models.efficientnet_v2_s(pretrained=False)

# Modify the input layer to accept grayscale images instead of RGB
# Identify the correct attribute based on the model structure
conv_layer = model.features[0][0]

new_conv_layer = nn.Conv2d(1, conv_layer.out_channels,
                           kernel_size=conv_layer.kernel_size,
                           stride=conv_layer.stride,
                           padding=conv_layer.padding,
                           bias=False)

new_conv_layer.requires_grad = False
model.features[0][0] = new_conv_layer

# Modify the output layer for binary classification
num_ftrs = model.classifier._modules['1'].in_features
model.classifier._modules['1'] = nn.Linear(num_ftrs, 1)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
model.load_state_dict(torch.load(f'EffNet_best1.pth'))

# Evaluate on test dataset
model.eval()
all_test_labels = []
all_test_preds = []
with torch.no_grad():
    for inputs, labels in tqdm(test_loader):
        inputs, labels = inputs.to('cuda'), labels.to('cuda').float().unsqueeze(1)
        outputs = model(inputs)
        test_preds = torch.sigmoid(outputs).cpu().numpy() > 0.02
        all_test_preds.extend(test_preds)
        all_test_labels.extend(labels.cpu().numpy())

# Calculate the confusion matrix
tn, fp, fn, tp = confusion_matrix(all_test_labels, all_test_preds).ravel()

# Calculate precision, accuracy, and recall
precision = precision_score(all_test_labels, all_test_preds)
accuracy = (tp + tn) / (tp + tn + fp + fn)
recall = recall_score(all_test_labels, all_test_preds)

print(f'Metrics: ')
print(f'True Positives: {tp}, True Negatives: {tn}, False Positives: {fp}, False Negatives: {fn}')
print(f'Precision: {precision:.4f}, Accuracy: {accuracy:.4f}, Recall: {recall:.4f}\n')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 100%|██████████| 43/43 [00:47<00:00,  1.09s/it]
# Metrics:
# True Positives: 59, True Negatives: 3383, False Positives: 1963, False Negatives: 57
# Precision: 0.0292, Accuracy: 0.6302, Recall: 0.5086

# %%
# !cp /content/EffNet_best1.pth /content/drive/MyDrive/

# %%
# Load the saved model
model = models.efficientnet_v2_s(pretrained=False)

# Modify the input layer to accept grayscale images instead of RGB
# Identify the correct attribute based on the model structure
conv_layer = model.features[0][0]

new_conv_layer = nn.Conv2d(1, conv_layer.out_channels,
                           kernel_size=conv_layer.kernel_size,
                           stride=conv_layer.stride,
                           padding=conv_layer.padding,
                           bias=False)

new_conv_layer.requires_grad = False
model.features[0][0] = new_conv_layer

# Modify the output layer for binary classification
num_ftrs = model.classifier._modules['1'].in_features
model.classifier._modules['1'] = nn.Linear(num_ftrs, 1)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
model.load_state_dict(torch.load(f'EffNet_best1.pth'))

# Evaluate on test dataset
model.eval()
all_test_labels = []
all_test_preds = []
with torch.no_grad():
    for inputs, labels in tqdm(test_loader):
        inputs, labels = inputs.to('cuda'), labels.to('cuda').float().unsqueeze(1)
        outputs = model(inputs)
        test_preds = torch.sigmoid(outputs).cpu().numpy() > 0.0206
        all_test_preds.extend(test_preds)
        all_test_labels.extend(labels.cpu().numpy())

# Calculate the confusion matrix
tn, fp, fn, tp = confusion_matrix(all_test_labels, all_test_preds).ravel()

# Calculate precision, accuracy, and recall
precision = precision_score(all_test_labels, all_test_preds)
accuracy = (tp + tn) / (tp + tn + fp + fn)
recall = recall_score(all_test_labels, all_test_preds)

print(f'Metrics: ')
print(f'True Positives: {tp}, True Negatives: {tn}, False Positives: {fp}, False Negatives: {fn}')
print(f'Precision: {precision:.4f}, Accuracy: {accuracy:.4f}, Recall: {recall:.4f}\n')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 100%|██████████| 43/43 [00:41<00:00,  1.04it/s]
# Metrics:
# True Positives: 54, True Negatives: 3527, False Positives: 1819, False Negatives: 62
# Precision: 0.0288, Accuracy: 0.6556, Recall: 0.4655
